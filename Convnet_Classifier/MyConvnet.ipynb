# %%
# %load training\ cnn.py
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
import utils.Convnet_Functions as CF

data_dir='/mnt/storage/home/robert/3D-Convnet-for-Alzheimer-s-Detection/data/Trains'
test_dir='/mnt/storage/home/robert/3D-Convnet-for-Alzheimer-s-Detection/data/Tests'

datanp=[]                               #images
labels=[]                               #labels
testnp=[]
testlabels=[]

for file in os.listdir(data_dir):
    data=np.load(os.path.join(data_dir,file), allow_pickle=True)
    datanp.append((data[0][0]))
    labels.append(data[0][1])

datanp = np.array(datanp)
labels = np.array(labels)

for file in os.listdir(test_dir):
    data=np.load(os.path.join(test_dir,file), allow_pickle=True)
    testnp.append((data[0][0]))
    testlabels.append(data[0][1])

testnp = np.array(testnp)
testlabels = np.array(testlabels)

sh = datanp.shape
testsh = testnp.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0a24efef0bb2> in <module>
#      14 testlabels=[]
#      15
# ---> 16 for file in os.listdir(data_dir):
#      17     data=np.load(os.path.join(data_dir,file), allow_pickle=True)
#      18     datanp.append((data[0][0]))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/home/robert/3D-Convnet-for-Alzheimer-s-Detection/data/Trains'

# %%
class_names = ['Autistic', 'TD']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(datanp[i,:,:,60,0], cmap=plt.cm.binary)
    plt.xlabel(class_names[labels[i][0]])
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
                nn.Conv3d(1, 32, 5, stride=2),
                nn.ReLU(),
                nn.MaxPool3d(3, stride=2))
        self.conv2 = nn.Sequential(
                nn.Conv3d(32, 64, 5, stride=2),
                nn.ReLU(),
                nn.BatchNorm3d(64),
                nn.LeakyReLU(),
                nn.MaxPool3d(2, stride=2),
                nn.Dropout(0.5))
        self.fc1 = nn.Sequential(
                nn.Linear(64*5*5*6, 64*5*5*3),
                nn.LeakyReLU(),
                nn.Dropout(0.4))
        self.fc2 = nn.Sequential(
                nn.Linear(64*5*5*3, 64*5*5),
                nn.LeakyReLU(),
                nn.Dropout(0.3))
        self.fc3 = nn.Sequential(
                nn.Linear(64*5*5, 64*5),
                nn.LeakyReLU(),
                nn.Dropout(0.3))
        self.fc4 = nn.Sequential(
                nn.Linear(64*5, 2))
        
    def forward(self,x):
        x = self.conv1(x)
        x = self.conv2(x)
        
        x = torch.flatten(x)
        xsh = x.size(-1)
        x = x.view(-1,xsh)
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        
        return F.softmax(x, dim=1)

# %%
loss_function = nn.MSELoss()

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")

# %%
def fwd_pass(x, y, train=False):
    if train:
        net.zero_grad()
    outputs = net(x)
    matches = [torch.argmax(i) == torch.argmax(j) for i,j in zip(outputs, y)]
    acc = matches.count(True)/len(matches)
    loss = loss_function(outputs, y)
    
    if train:
        loss.backward()
        optimizer.step()
    return acc, loss

# %%
import time

MODEL_NAME = f"model-{int(time.time())}"

net = Net().to(device)
optimizer = optim.Adam(net.parameters(), lr=0.001)
loss_function = nn.MSELoss()

print(MODEL_NAME)

def train(epochs):
    BATCH_SIZE = 10
    EPOCHS = epochs
    
    with open("model.log", "a") as f:
            for i in tqdm(range(0,len(train_X), BATCH_SIZE)):
                batch_X = train_X[i:i+BATCH_SIZE].view(-1,BATCH_SIZE,106,106,120).to(device)
                batch_y = train_y[i:i+BATCH_SIZE].to(device)
                
                acc, loss = fwd_pass(batch_X, batch_y, train=True)
                if i % 50 == 0:
                    val_acc, val_loss = test(size=BATCH_SIZE)
                    f.write(f"{MODEL_NAME},{round(time.time(),3)}, {round(float(acc),2)}, {round(float(loss),4)}, {round(float(val_acc),2)}, {round(float(val_loss),4)}\n")
